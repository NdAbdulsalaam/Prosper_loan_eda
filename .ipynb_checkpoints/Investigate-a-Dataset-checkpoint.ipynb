# %% [markdown]
# # Project:TMDb movie data
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > What can we say about the success of a movie before it is released? Are there certain companies (Pixar?) that have found a consistent formula? Given that major films costing over $100 million to produce can still flop, this question is more important than ever to the industry. Film aficionados might have different interests. Can we predict which films will be highly rated, whether or not they are a commercial success?
#
# > This data set contains information about 10,000 movies collected from The Movie Database (TMDb), including user ratings and revenue.
#
# > The dataset contains the following features:-
# - id - A unique identifier for each movie.
# - cast - The name of lead and supporting actors.
# - crew - The name of Director, Editor, Composer, Writer etc.
# - budget - The budget in which the movie was made.
# - genre - The genre of the movie, Action, Comedy ,Thriller etc.
# - homepage - A link to the homepage of the movie.
# - original_title - The title of the movie before translation or adaptation.
# - overview - A brief description of the movie.
# - popularity - A numeric quantity specifying the movie popularity.
# - production_companies - The production house of the movie.
# - release_date - The date on which it was released.
# - revenue - The worldwide revenue generated by the movie.
# - runtime - The running time of the movie in minutes.
# - tagline - Movie's tagline.
# - title - Title of the movie.
# - vote_count - the count of votes recieved.
# - release_year = the year the movie was released
# - vote_average - average ratings the movie recieved.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# ## Checking for the number of rows and columns

# %%
df.shape
# Out:
# (10866, 21)

# %% [markdown]
# ## Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.loc[df.duplicated() == True]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ...  \
# 2090  Dwight H. Little  Survival is no game  ...
#
#                                                overview runtime  \
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10        110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Checking for null values

# %%
df.isnull().sum().sum()
# Out:
# 13434

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# ## Quick insight using `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# ## Quick insight using `.describe()`

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %% [markdown]
# <a id='wrangling'></a>
# ## **Data Wrangling**

# %% [markdown]
# ## Remove duplicates

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ## Remove extranous columns.
# **These include:**
# - id
# - imdb_id
# - homepage
# - tagline
# - budget_adj
# - revenue_adj

# %%
drop_cols = ['id', 'imdb_id', 'tagline', 'homepage', 'budget_adj', 'revenue_adj']
df.drop(columns=drop_cols, inplace = True)

# %%
df.isnull().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# director                  44
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# dtype: int64

# %% [markdown]
# ### let check for the total number of rows with missing values

# %%
df_null = df[df.isnull().any(axis = 1)]

# %%
df_null.shape
# Out:
# (2199, 15)

# %%
print(f'''Total number of row in the dataset: {df.shape[0]}
Total number of rows with missing values: {df_null.shape[0]}
Percentage of missing rows: {round((df_null.shape[0]/df.shape[0] * 100), 2)}%''')
# Out:
# Total number of row in the dataset: 10865
# Total number of rows with missing values: 2199
# Percentage of missing rows: 20.24%

# %% [markdown]
# ## Drop null values

# %%
df.dropna(inplace = True)

## Confirm the new number of rows
print(f'''Total row: {df.shape[0]}
Total null: {df.isnull().sum().sum()}''')
# Out:
# Total row: 8666
# Total null: 0

# %% [markdown]
# ## Data Cleaning and Engineering

# %% [markdown]
# ## Fix incorrect datatypes:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8666 entries, 0 to 10865
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            8666 non-null   float64
#  1   budget                8666 non-null   int64
#  2   revenue               8666 non-null   int64
#  3   original_title        8666 non-null   object
#  4   cast                  8666 non-null   object
#  5   director              8666 non-null   object
#  6   keywords              8666 non-null   object
#  7   overview              8666 non-null   object
#  8   runtime               8666 non-null   int64
#  9   genres                8666 non-null   object
#  10  production_companies  8666 non-null   object
#  11  release_date          8666 non-null   object
#  12  vote_count            8666 non-null   int64
#  13  vote_average          8666 non-null   float64
#  14  release_year          8666 non-null   int64
# ...

# %% [markdown]
# ## Rename `original_title` as `title`

# %%
df.rename(columns= {'original_title': 'title'}, inplace= True)

# %% [markdown]
# ## Change release_date to datetime and create the month and day columns for easy analysis

# %%
## Convert to datetime
df['release_date'] = pd.to_datetime(df.release_date)

## Create release_month and release date name
df['release_month'] = df['release_date'].dt.month_name()
df['release_day'] = df['release_date'].dt.day_name()

## Drop the release_date column
df.drop(columns=['release_date'], inplace = True)

## Confirm changes
df.head(2)
# Out:
#    popularity     budget     revenue               title  \
# 0   32.985763  150000000  1513528810      Jurassic World
# 1   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...    George Miller
#
#                                             keywords  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island
# 1   future|chase|post-apocalyptic|dystopia|australia
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies  vote_count  \
# ...

# %% [markdown]
# ## Create the `profit` column from `revenue` and `budget` and drop them
# > Since profit is the sole of business

# %%
df['profit'] = df.revenue - df.budget
df.drop(columns= ['revenue', 'budget'], inplace = True)

## Confirm changes
df.head(3)
# Out:
#    popularity               title  \
# 0   32.985763      Jurassic World
# 1   28.419936  Mad Max: Fury Road
# 2   13.112507           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
#
#                                             keywords  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island
# 1   future|chase|post-apocalyptic|dystopia|australia
# 2  based on novel|revolution|dystopia|sequel|dyst...
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
#
#                                       genres  \
# ...

# %% [markdown]
# ## Re-write the keywords and genres columns
# > This will made the word in the columns readable

# %%
df['keywords'] = df['keywords'].apply(lambda x: x.replace("|", " "))
df['cast'] = df['cast'].apply(lambda x: x.replace("|", ", "))
df['genres'] = df['genres'].apply(lambda x: x.replace("|", ", "))
df['production_companies'] = df['production_companies'].apply(lambda x: x.replace("|", ", "))

## Confirm changes
df.head(3)
# Out:
#    popularity               title  \
# 0   32.985763      Jurassic World
# 1   28.419936  Mad Max: Fury Road
# 2   13.112507           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt, Bryce Dallas Howard, Irrfan Khan,...   Colin Trevorrow
# 1  Tom Hardy, Charlize Theron, Hugh Keays-Byrne, ...     George Miller
# 2  Shailene Woodley, Theo James, Kate Winslet, An...  Robert Schwentke
#
#                                             keywords  \
# 0  monster dna tyrannosaurus rex velociraptor island
# 1   future chase post-apocalyptic dystopia australia
# 2  based on novel revolution dystopia sequel dyst...
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
#
#                                          genres  \
# ...

# %% [markdown]
# ## Categorizing the runtime using `pandas cut` into
# - Short
# - Moderate
# - Long
# - Very long
#
# **Why:**<br>
# This values are so many that it cannot be used for analysis (no meaniful inference can bo gotten) unlesss categorized

# %%
df.runtime.nunique()
# Out:
# 216

# %%
df.runtime.describe()
# Out:
# count    8666.000000
# mean      103.815140
# std        26.207186
# min         0.000000
# 25%        91.000000
# 50%       100.000000
# 75%       113.000000
# max       705.000000
# Name: runtime, dtype: float64

# %%
bin_edges = [0, 30, 60, 120, 705]
bin_names = ['Short', 'Moderate', 'Long', 'Very long']
df['duration'] = pd.cut(df.runtime, bin_edges, labels = bin_names)

## Confirm chages
df.head(3)
# Out:
#    popularity               title  \
# 0   32.985763      Jurassic World
# 1   28.419936  Mad Max: Fury Road
# 2   13.112507           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt, Bryce Dallas Howard, Irrfan Khan,...   Colin Trevorrow
# 1  Tom Hardy, Charlize Theron, Hugh Keays-Byrne, ...     George Miller
# 2  Shailene Woodley, Theo James, Kate Winslet, An...  Robert Schwentke
#
#                                             keywords  \
# 0  monster dna tyrannosaurus rex velociraptor island
# 1   future chase post-apocalyptic dystopia australia
# 2  based on novel revolution dystopia sequel dyst...
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
#
#                                          genres  \
# ...

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ## Define function for resuability

# %%
def barhplot(x, y, xlabel, title):
    plt.figure(figsize=  (14, 8))
    plt.barh(x, y, align = 'center')
    plt.gca().invert_yaxis()
    plt.xlabel(xlabel, fontsize = 18)
    plt.title(title, fontsize = 18)
    plt.show();

def barplot(x, y, xlabel, title):
    plt.figure(figsize=  (10, 7))
    plt.bar(x, y, align = 'center')
    plt.xlabel(xlabel, fontsize = 18)
    plt.title(title, fontsize = 18)
    plt.show();

def lineplot(value, xlabel, ylabel, title):
    plt.figure(figsize=  (17, 9))
    plt.plot(value)
    plt.xlabel(xlabel, fontsize = 18)
    plt.ylabel(ylabel, fontsize = 18)
    plt.title(title, fontsize = 23)
    plt.show();

def sortby(column):
    df1 = df.sort_values(by = column, ascending = False)
    return df1

# %% [markdown]
# ## Q1. First 10 most popular movie
# > This is to check for the tiltes of the first ten most popular movies among the people

# %%
top = df.sort_values(by = 'popularity', ascending = False)
top_10 = top[['title', 'popularity']].head(10)
top_10.drop
# Out:
# <bound method DataFrame.drop of                                       title  popularity
# 0                            Jurassic World   32.985763
# 1                        Mad Max: Fury Road   28.419936
# 629                            Interstellar   24.949134
# 630                 Guardians of the Galaxy   14.311205
# 2                                 Insurgent   13.112507
# 631     Captain America: The Winter Soldier   12.971027
# 1329                              Star Wars   12.037933
# 632                               John Wick   11.422751
# 3              Star Wars: The Force Awakens   11.173104
# 633   The Hunger Games: Mockingjay - Part 1   10.739009>

# %%
barhplot(top_10.title, top_10.popularity, 'popularity', 'First 10 Most Popular Movies')

# %% [markdown]
# The first ten most popular movies include Jurassic World, Mad Max: Fury Roaad, etc

# %% [markdown]
# ## Q2. What are the attributes of most popular movies
# > This is to check for numerical parameter that most be fufilled for a movie to become popular and the benefi to get as a producer

# %%
top.describe()
# Out:
#         popularity      runtime   vote_count  vote_average  release_year  \
# count  8666.000000  8666.000000  8666.000000   8666.000000   8666.000000
# mean      0.741937   103.815140   264.204823      6.003612   2000.129818
# std       1.087657    26.207186   635.195808      0.893539     13.221278
# min       0.000188     0.000000    10.000000      1.500000   1960.000000
# 25%       0.249990    91.000000    20.000000      5.500000   1993.000000
# 50%       0.449377   100.000000    54.000000      6.100000   2004.000000
# 75%       0.842984   113.000000   200.000000      6.600000   2011.000000
# max      32.985763   705.000000  9767.000000      8.700000   2015.000000
#
#              profit
# count  8.666000e+03
# mean   3.153926e+07
# std    1.069616e+08
# min   -4.139124e+08
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.966175e+07
# max    2.544506e+09

# %% [markdown]
# - For a movie to be popuplar, it should have a run time of approximately 104 minutes and vote_count of about 264
# - This will increase the profit to about 32.5 million

# %% [markdown]
# ## Q3. How does keywords affect the popularity of a movie
# > To have an insight on the desccriptive words that are normally used for these movies

# %%
top_key = sortby('popularity')
top_key[['keywords', 'popularity', 'title']].head(5)
# Out:
#                                               keywords  popularity  \
# 0    monster dna tyrannosaurus rex velociraptor island   32.985763
# 1     future chase post-apocalyptic dystopia australia   28.419936
# 629  saving the world artificial intelligence fathe...   24.949134
# 630  marvel comic spaceship space scene during end ...   14.311205
# 2    based on novel revolution dystopia sequel dyst...   13.112507
#
#                        title
# 0             Jurassic World
# 1         Mad Max: Fury Road
# 629             Interstellar
# 630  Guardians of the Galaxy
# 2                  Insurgent

# %%
barhplot(top_key.keywords[0:10], top_key.popularity[0:10], "Popularity", "First 10 most Popular Movies")

# %% [markdown]
# It can be deduced here the most of the movies on the list are scientific in nature from their keyword

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ## Q4. Highly rated
# > To check of popularity of a movie is a factor of hoe high it's rated

# %%
vote = sortby('vote_average')
top_vote = vote[['title', 'vote_average']].head(10)
top_vote
# Out:
#                                                  title  vote_average
# 6911                                 Pink Floyd: Pulse           8.7
# 8411                             Queen - Rock Montreal           8.5
# 3690                                 The Art of Flight           8.5
# 4178                          The Shawshank Redemption           8.4
# 5986                                 Guten Tag, RamÃ³n           8.4
# 609      The Jinx: The Life and Deaths of Robert Durst           8.4
# 7948                                 Stop Making Sense           8.4
# 3310  Dear Zachary: A Letter to a Son About His Father           8.3
# 2313                                    Tick Tock Tale           8.3
# 1864                           Iron Maiden: Flight 666           8.3

# %%
barhplot(top_vote.title, top_vote.vote_average, "Popularity", "First 10 most Popular Movies")

# %% [markdown]
# The result shows the two parameters, popularity and vote, are not directly proportional

# %% [markdown]
# ## Q5. Checking the influence of duration on popularity and profit

# %%
duration_pop = df.groupby(['duration']).mean()['popularity']
duration_pop.sort_values(ascending= False)
# Out:
# duration
# Very long    1.248461
# Long         0.651793
# Short        0.459411
# Moderate     0.274689
# Name: popularity, dtype: float64

# %%
barplot(duration_pop.index, duration_pop, "Popularity", "Popularity of movies based on the duration")

# %% [markdown]
# supprisingly, on average, the longer the movie, the more popular it is.
# Then, we need to check if profit also follow thesame trend

# %%
duration_prof = df.groupby(['duration']).mean()['profit']
duration_pop.sort_values(ascending= False)
# Out:
# duration
# Very long    1.248461
# Long         0.651793
# Short        0.459411
# Moderate     0.274689
# Name: popularity, dtype: float64

# %%
barplot(duration_prof.index, duration_prof, "Profit", "Profit from movies based on the duration")

# %% [markdown]
# That awesom, the profit also increases as the duration increasea and perphaps, with increase in popularity

# %% [markdown]
# ## Q6. Checking the influence of the day a movie was on popularity and profit
# > To check on which days are the popular moviese rerleased so that they can be target for future release

# %%
day_pop = df.groupby(['release_day']).mean()['popularity']
day_pop.sort_values(ascending= False)
# Out:
# release_day
# Wednesday    1.046971
# Thursday     0.907663
# Tuesday      0.729910
# Monday       0.702053
# Friday       0.636682
# Sunday       0.558103
# Saturday     0.542088
# Name: popularity, dtype: float64

# %%
barplot(day_pop.index, day_pop, "Popularity", "Popularity of movies based on the day it was released")

# %% [markdown]
# From the graph above, movies are better released between Mondays to Thursdays. Early days of the week. Then, we need to check if profit also follow thesame trend

# %%
day_prof = df.groupby(['release_day']).mean()['profit']
day_prof.sort_values(ascending= False)
# Out:
# release_day
# Wednesday    5.744613e+07
# Thursday     4.358354e+07
# Tuesday      3.704923e+07
# Monday       3.582095e+07
# Friday       2.081881e+07
# Sunday       1.721086e+07
# Saturday     1.252642e+07
# Name: profit, dtype: float64

# %%
barplot(day_prof.index, day_prof, "Profit", "Profit from movies based on the day it was released")

# %% [markdown]
# As the first graph, movies are better released between Mondays to Thursdays. Weekends are out of it

# %% [markdown]
# ## Q7. Checking the influence of the month a movie was released on popularity and profit
# > To check on which months are the popular moviese rerleased so that they can be target for future release

# %%
month_pop = df.groupby(['release_month']).mean()['popularity'].sort_values(ascending= False)
month_pop
# Out:
# release_month
# June         0.908816
# November     0.866646
# July         0.857632
# May          0.855181
# December     0.854900
# March        0.746987
# October      0.702567
# February     0.668109
# August       0.653187
# April        0.645327
# September    0.630807
# January      0.554892
# Name: popularity, dtype: float64

# %%
barhplot(month_pop.index, month_pop, "popularity", "Popularity of a movies based on the month it was released")

# %% [markdown]
# From the graph above, movies are better released between May to July, or November and December. Early days of the week. Then, we need to check if profit also follow the same trend

# %%
month_prof = df.groupby(['release_month']).sum()['profit'].sort_values(ascending= False)
month_prof
# Out:
# release_month
# June         43806655927
# December     38440122065
# May          34346594407
# November     30493854871
# July         29518226018
# March        19223428454
# October      16300150008
# April        15885471649
# August       14356556697
# September    13465619027
# February     10627155845
# January       6855390876
# Name: profit, dtype: int64

# %%
barhplot(month_prof.index, month_prof, "popularity", "Popularity of a movies based on the month it was released")

# %% [markdown]
# From this graph, it'll be a good advice to that a movie is released in June, December or at least May.

# %% [markdown]
# ## Q8. Changed in the profit made from movies over the years
# > To check for the future of the industry. Where it was in the past, where it is and perhaps, where it is going

# %%
top_year = df.groupby('release_year').sum()['profit'].sort_values(ascending= False)
top_year[0:5]
# Out:
# release_year
# 2015    19188039506
# 2012    16386295850
# 2014    16295928255
# 2013    15319942280
# 2011    14643137595
# Name: profit, dtype: int64

# %%
lineplot(top_year, "Year", "Profit", "Changed in the profit made from movies over the years")

# %% [markdown]
# ## **Greate! The future is bright for the film industry.**

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# ### Findings:
# > It has been gathered that movies like Jurassic World	32.985763, Mad Max: Fury Road, Interstellar, etc are well know by the people. However, this does not relate to higher rating nor increase in profit. Instead, movies like Pink Floyd: Pulse, Queen - Rock Montreal, The Art of Flight, The Shawshank Redemption	 are not popularly known but are highly rated.
# > Also, it has been established that the duration of a movie, day, monthe and year of release of a movie affect its popularity and most importantly, profit.<br>
# > Lastly, It is a good thing to note the upward trend in the film industry over the year.And, based on this, the following conclusions were reached:
# - The best day of the week to release a movie is Wednesday
# - The best month of the year to release a movie is Wednesday
# - That the future is bright for the film industry
#
# ### Limitations:
# - The number of rows with misssing values are to many (2199 after dropping extraneous columns). This reduced the total number of available data
# - Get the time of release (perhaps in the release_date column)would have been helpful in determining when people normally get time for movies
# - Having a single (most appropriate class) for columns like genres would have made it easy to determine which genre of movies are highly rated.

# %% [markdown]
# ## References

# %% [markdown]
# <li><a href="https://stackoverflow.com"> Stack over flow</a></li>
# <li><a href="https://www.geeksforgeeks.org">Geeks for geeks</a></li>
# <li><a href="https://pandas.pydata.org">Pandas documentation</a></li>
# <li><a href="https://towardsdatascience.com">Towards data science</a></li>
# <li><a href="https://matplotlib.org">Matplotlib documentation</a></li>
# <li><a href="https://realpython.com">real pthon</a></li>
